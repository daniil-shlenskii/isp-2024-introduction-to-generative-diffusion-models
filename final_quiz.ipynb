# %% [markdown]
# 1. Write down the specific expression of distribution $q(x_t | x_{t-1})$.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 2. Write down the specific expression of distribution $q(x_t | x_0)$.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 3. It's intractable to evaluate reverse transition kernel $q(x_{t - 1} | x_t)$, so we decided to approximate it with a parametric model $p_\theta(x_{t - 1} | x_t) = \mathcal{N}(x_{t - 1} | \mu_\theta(x_t, t), \Sigma_\theta(x_t, t))$.
# Why such a choice of a model is valid?

# %% [markdown]
# `your_answer`

# %% [markdown]
# 4. For DDPM model objective has the following view: $L_{\text{simple}} = \mathbb{E}_{t \sim U[1, T]}
#  L_t$. Write down the exact expression for the $L_t$ term.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 5. Write down a training procedure of DDPM model.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 6. Write down a sampling with DDPM model procedure.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 7. Write down the connection between $\hat{x}^{0}_\theta$, $\mu_\theta$, $s_\theta$ paramatrizations and $\epsilon_{\theta}$ parametrization

# %% [markdown]
# `your_answer`

# %% [markdown]
# 8. Let's consider iDDPM faster sampling approach. Explain how to find $\{\alpha^{new}_i\}_{i=1}^T$ for shorter Markov chain.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 9. Let's consider iDDPM faster sampling approach. Write down the obtained sampling process.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 10. Let's consider DDIM sampling approach. Name, at least, two idealogical differences from the DDPM sampling approach.

# %% [markdown]
# `your_answer`

# %% [markdown]
# 11. Let's consider the techique cosidered on the lectures called `Classifier guidance 1`. How the sampling process is being changed using that?

# %% [markdown]
# `your_answer`

# %% [markdown]
# 12. Is it suitable for DDIM sampling? Why?

# %% [markdown]
# `your_answer`

# %% [markdown]
# 13. Let's consider the technique cosidered on the lectures called `Classifier guidance 2'. How the sampling process is being changed using that?

# %% [markdown]
# `your_answer`

# %% [markdown]
# 14. Can we use a text as a label here?

# %% [markdown]
# `your_answer`

# %% [markdown]
# 15. Let's consider the technique cosidered on the lectures called `Classifier-free guidance'. How the sampling process is being changed using that?

# %% [markdown]
# `your_answer`
